# %%
# %load_ext autoreload
# %autoreload 2
# %config Completer.use_jedi = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from get_data import *
import sklearn as sk
import pandas as pd
import numpy as np

# %%
x = get_data(fill_missing_data= False,force_reload=True)
# Out:
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?
# force reload?
# loading?

# %%
x[0]
# Out:
#                Session_Entry  Location
# Session_Entry
# 0                     4380.0       142
# 10080                14460.0       145
# 20310                24690.0       145
# 20320                24700.0       145
# 30450                34830.0       145
# ...                      ...       ...
# 14813110          14817490.0       134
# 14823180          14827560.0       145
# 14823190          14827570.0       145
# 14833320          14837700.0       142
# 14843430          14847810.0       145
#
# [4226 rows x 2 columns]

# %%
train,test_X,test_y = test_train_split(x,lookback = 1000)

# %%
train
# Out:
# [array([[ 142],
#         [2956],
#         [2956],
#         ...,
#         [2956],
#         [2956],
#         [2956]], dtype=int64)]
